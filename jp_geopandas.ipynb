# %% [markdown]
# Geopandas
# ---

# %%
import geopandas as gp

import matplotlib.pyplot as plt

world=gp.read_file(gp.datasets.get_path('naturalearth_lowres'))
world.plot()
plt.show()

# %%
file="D:/code/Python Code/data/map/china.json"
china_main=gp.read_file(file)
shanxi=gp.read_file("D:/code/Python Code/data/map/province_610000.json")#陕西
fig,ax=plt.subplots(figsize=(12,8))#,dpi=80
ax=china_main.plot(ax=ax,color='darkslategray')
ax=shanxi.plot(ax=ax,color='midnightblue')
# ax=china_main.plot(ax=ax,color='midnightblue')
plt.show()

# %%
import pandas as pd
data=pd.read_excel('D:/code/Python Code/data/earthquake_data/data_test.xlsx')

fig,ax=plt.subplots(figsize=(12,8))#,dpi=80
ax=china_main.plot(ax=ax,color='midnightblue',figsize=(16,8))#底图
